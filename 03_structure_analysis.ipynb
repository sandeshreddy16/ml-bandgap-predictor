# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from pymatgen.core import Structure, Composition, Lattice      
print("Imports done")
# Out:
# Imports done

# %%
lattice=Lattice.cubic(5.43) #
si = Structure(  
    lattice,["Si","Si"],[[0,0,0],[0.25,0.25,0.25]])       
print(f"formula: {si.formula}")
print(f"atoms: {si.num_sites}") 
print(f"volume:{si.volume:.2f}") 
print(f"density:{si.density:.3f}") 
print(si.composition)
print(f"mass: {si.composition.weight}")
# Out:
# formula: Si2
# atoms: 2
# volume:160.10
# density:0.583
# Si2
# mass: 56.171 amu

# %%
from pymatgen.core import Element
comp=Composition("GaAs")
print(f"Elements: {list(comp.elements)}")
ga=Element("Ga") 
print(f"Atomic number: {ga.Z}")
print(f"electronegativity: {ga.X}")
print(f"atomic radius: {ga.atomic_radius}")
print(f"atomic weight: {ga.atomic_mass}")
# Out:
# Elements: [Element Ga, Element As]
# Atomic number: 31
# electronegativity: 1.81
# atomic radius: 1.3 ang
# atomic weight: 69.723 amu

# %%
from mp_api.client import MPRester
import os
api_key = os.environ.get("MP_API_KEY")
with MPRester(api_key) as mpr:
    entries=mpr.materials.summary.search(
        band_gap=(0.5,3.5),
        num_elements=(2,3),
        num_sites=(2,10),
        fields=["material_id","formula_pretty","band_gap", "formation_energy_per_atom","structure"])
print(f"downloaded {len(entries)} structures with 3D geometry!")
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/4184 [00:00<?, ?it/s]
# downloaded 4184 structures with 3D geometry!

# %%
rows=[]
for entry in entries:
    s=entry.structure
    elements=list(s.composition.elements)
    rows.append({
    "formula": entry.formula_pretty,
    "bandgap": entry.band_gap,
    "formation_energy": entry.formation_energy_per_atom,
    "n_sites": s.num_sites,
    "volume": s.volume,
    "density": s.density,
    "volume_per_atm":s.volume / s.num_sites,
    "n_elements": len(elements),
    "mean_electronegativity":np.mean([e.X for e in elements]),
    "electronegativity_diff": max([e.X for e in elements])-min([e.X for e in elements]),
    "mean_atomicmass":np.mean([e.atomic_mass for e in elements]),
    "mean_row": np.mean([e.row for e in elements]),
    "mean_group": np.mean([e.group for e in elements]),
    })
    df_struct=pd.DataFrame(rows)
    df_struct.to_csv("structures_data.csv",index=False)
    print(f"Saved {len(df_struct)} structures with features")
# Out:
# Saved 1 structures with features
# Saved 2 structures with features
# Saved 3 structures with features
# Saved 4 structures with features
# Saved 5 structures with features
# Saved 6 structures with features
# Saved 7 structures with features
# Saved 8 structures with features
# Saved 9 structures with features
# Saved 10 structures with features
# Saved 11 structures with features
# Saved 12 structures with features
# Saved 13 structures with features
# Saved 14 structures with features
# Saved 15 structures with features
# Saved 16 structures with features
# Saved 17 structures with features
# Saved 18 structures with features
# Saved 19 structures with features
# Saved 20 structures with features
# Saved 21 structures with features
# Saved 22 structures with features
# Saved 23 structures with features
# Saved 24 structures with features
# Saved 25 structures with features
# Saved 26 structures with features
# Saved 27 structures with features
# Saved 28 structures with features
# Saved 29 structures with features
# Saved 30 structures with features
# Saved 31 structures with features
# Saved 32 structures with features
# Saved 33 structures with features
# Saved 34 structures with features
# Saved 35 structures with features
# Saved 36 structures with features
# Saved 37 structures with features
# Saved 38 structures with features
# Saved 39 structures with features
# Saved 40 structures with features
# Saved 41 structures with features
# Saved 42 structures with features
# Saved 43 structures with features
# Saved 44 structures with features
# Saved 45 structures with features
# Saved 46 structures with features
# Saved 47 structures with features
# Saved 48 structures with features
# Saved 49 structures with features
# Saved 50 structures with features
# Saved 51 structures with features
# Saved 52 structures with features
# Saved 53 structures with features
# Saved 54 structures with features
# Saved 55 structures with features
# Saved 56 structures with features
# Saved 57 structures with features
# Saved 58 structures with features
# Saved 59 structures with features
# Saved 60 structures with features
# Saved 61 structures with features
# Saved 62 structures with features
# Saved 63 structures with features
# Saved 64 structures with features
# Saved 65 structures with features
# Saved 66 structures with features
# Saved 67 structures with features
# Saved 68 structures with features
# Saved 69 structures with features
# Saved 70 structures with features
# Saved 71 structures with features
# Saved 72 structures with features
# Saved 73 structures with features
# Saved 74 structures with features
# Saved 75 structures with features
# Saved 76 structures with features
# Saved 77 structures with features
# Saved 78 structures with features
# Saved 79 structures with features
# Saved 80 structures with features
# Saved 81 structures with features
# Saved 82 structures with features
# Saved 83 structures with features
# Saved 84 structures with features
# Saved 85 structures with features
# Saved 86 structures with features
# Saved 87 structures with features
# Saved 88 structures with features
# Saved 89 structures with features
# Saved 90 structures with features
# Saved 91 structures with features
# Saved 92 structures with features
# Saved 93 structures with features
# Saved 94 structures with features
# Saved 95 structures with features
# Saved 96 structures with features
# Saved 97 structures with features
# Saved 98 structures with features
# Saved 99 structures with features
# Saved 100 structures with features
# Saved 101 structures with features
# Saved 102 structures with features
# Saved 103 structures with features
# Saved 104 structures with features
# Saved 105 structures with features
# Saved 106 structures with features
# Saved 107 structures with features
# Saved 108 structures with features
# Saved 109 structures with features
# Saved 110 structures with features
# Saved 111 structures with features
# Saved 112 structures with features
# Saved 113 structures with features
# Saved 114 structures with features
# Saved 115 structures with features
# Saved 116 structures with features
# Saved 117 structures with features
# Saved 118 structures with features
# Saved 119 structures with features
# Saved 120 structures with features
# Saved 121 structures with features
# Saved 122 structures with features
# Saved 123 structures with features
# Saved 124 structures with features
# Saved 125 structures with features
# Saved 126 structures with features
# Saved 127 structures with features
# Saved 128 structures with features
# Saved 129 structures with features
# Saved 130 structures with features
# Saved 131 structures with features
# Saved 132 structures with features
# Saved 133 structures with features
# Saved 134 structures with features
# Saved 135 structures with features
# Saved 136 structures with features
# Saved 137 structures with features
# Saved 138 structures with features
# Saved 139 structures with features
# Saved 140 structures with features
# Saved 141 structures with features
# Saved 142 structures with features
# Saved 143 structures with features
# Saved 144 structures with features
# Saved 145 structures with features
# Saved 146 structures with features
# Saved 147 structures with features
# Saved 148 structures with features
# Saved 149 structures with features
# Saved 150 structures with features
# Saved 151 structures with features
# Saved 152 structures with features
# Saved 153 structures with features
# Saved 154 structures with features
# Saved 155 structures with features
# Saved 156 structures with features
# Saved 157 structures with features
# Saved 158 structures with features
# Saved 159 structures with features
# Saved 160 structures with features
# Saved 161 structures with features
# Saved 162 structures with features
# Saved 163 structures with features
# Saved 164 structures with features
# Saved 165 structures with features
# Saved 166 structures with features
# Saved 167 structures with features
# Saved 168 structures with features
# Saved 169 structures with features
# Saved 170 structures with features
# Saved 171 structures with features
# Saved 172 structures with features
# Saved 173 structures with features
# Saved 174 structures with features
# Saved 175 structures with features
# Saved 176 structures with features
# Saved 177 structures with features
# Saved 178 structures with features
# Saved 179 structures with features
# Saved 180 structures with features
# Saved 181 structures with features
# Saved 182 structures with features
# Saved 183 structures with features
# Saved 184 structures with features
# Saved 185 structures with features
# Saved 186 structures with features
# Saved 187 structures with features
# Saved 188 structures with features
# Saved 189 structures with features
# Saved 190 structures with features
# Saved 191 structures with features
# Saved 192 structures with features
# Saved 193 structures with features
# Saved 194 structures with features
# Saved 195 structures with features
# Saved 196 structures with features
# Saved 197 structures with features
# Saved 198 structures with features
# Saved 199 structures with features
# Saved 200 structures with features
# Saved 201 structures with features
# Saved 202 structures with features
# Saved 203 structures with features
# Saved 204 structures with features
# Saved 205 structures with features
# Saved 206 structures with features
# Saved 207 structures with features
# Saved 208 structures with features
# Saved 209 structures with features
# Saved 210 structures with features
# Saved 211 structures with features
# Saved 212 structures with features
# Saved 213 structures with features
# Saved 214 structures with features
# Saved 215 structures with features
# Saved 216 structures with features
# Saved 217 structures with features
# Saved 218 structures with features
# Saved 219 structures with features
# Saved 220 structures with features
# Saved 221 structures with features
# Saved 222 structures with features
# Saved 223 structures with features
# Saved 224 structures with features
# Saved 225 structures with features
# Saved 226 structures with features
# Saved 227 structures with features
# Saved 228 structures with features
# Saved 229 structures with features
# Saved 230 structures with features
# Saved 231 structures with features
# Saved 232 structures with features
# Saved 233 structures with features
# Saved 234 structures with features
# Saved 235 structures with features
# Saved 236 structures with features
# Saved 237 structures with features
# Saved 238 structures with features
# Saved 239 structures with features
# Saved 240 structures with features
# Saved 241 structures with features
# Saved 242 structures with features
# Saved 243 structures with features
# Saved 244 structures with features
# Saved 245 structures with features
# Saved 246 structures with features
# Saved 247 structures with features
# Saved 248 structures with features
# Saved 249 structures with features
# Saved 250 structures with features
# Saved 251 structures with features
# Saved 252 structures with features
# Saved 253 structures with features
# Saved 254 structures with features
# Saved 255 structures with features
# Saved 256 structures with features
# Saved 257 structures with features
# Saved 258 structures with features
# Saved 259 structures with features
# Saved 260 structures with features
# Saved 261 structures with features
# Saved 262 structures with features
# Saved 263 structures with features
# Saved 264 structures with features
# Saved 265 structures with features
# Saved 266 structures with features
# Saved 267 structures with features
# Saved 268 structures with features
# Saved 269 structures with features
# Saved 270 structures with features
# Saved 271 structures with features
# Saved 272 structures with features
# Saved 273 structures with features
# Saved 274 structures with features
# Saved 275 structures with features
# Saved 276 structures with features
# Saved 277 structures with features
# Saved 278 structures with features
# Saved 279 structures with features
# Saved 280 structures with features
# Saved 281 structures with features
# Saved 282 structures with features
# Saved 283 structures with features
# Saved 284 structures with features
# Saved 285 structures with features
# Saved 286 structures with features
# Saved 287 structures with features
# Saved 288 structures with features
# Saved 289 structures with features
# Saved 290 structures with features
# Saved 291 structures with features
# Saved 292 structures with features
# Saved 293 structures with features
# Saved 294 structures with features
# Saved 295 structures with features
# Saved 296 structures with features
# Saved 297 structures with features
# Saved 298 structures with features
# Saved 299 structures with features
# Saved 300 structures with features
# Saved 301 structures with features
# Saved 302 structures with features
# Saved 303 structures with features
# Saved 304 structures with features
# Saved 305 structures with features
# Saved 306 structures with features
# Saved 307 structures with features
# Saved 308 structures with features
# Saved 309 structures with features
# Saved 310 structures with features
# Saved 311 structures with features
# Saved 312 structures with features
# Saved 313 structures with features
# Saved 314 structures with features
# Saved 315 structures with features
# Saved 316 structures with features
# Saved 317 structures with features
# Saved 318 structures with features
# Saved 319 structures with features
# Saved 320 structures with features
# Saved 321 structures with features
# Saved 322 structures with features
# Saved 323 structures with features
# Saved 324 structures with features
# Saved 325 structures with features
# Saved 326 structures with features
# Saved 327 structures with features
# Saved 328 structures with features
# Saved 329 structures with features
# Saved 330 structures with features
# Saved 331 structures with features
# Saved 332 structures with features
# Saved 333 structures with features
# Saved 334 structures with features
# Saved 335 structures with features
# Saved 336 structures with features
# Saved 337 structures with features
# Saved 338 structures with features
# Saved 339 structures with features
# Saved 340 structures with features
# Saved 341 structures with features
# Saved 342 structures with features
# Saved 343 structures with features
# Saved 344 structures with features
# Saved 345 structures with features
# Saved 346 structures with features
# Saved 347 structures with features
# Saved 348 structures with features
# Saved 349 structures with features
# Saved 350 structures with features
# Saved 351 structures with features
# Saved 352 structures with features
# Saved 353 structures with features
# Saved 354 structures with features
# Saved 355 structures with features
# Saved 356 structures with features
# Saved 357 structures with features
# Saved 358 structures with features
# Saved 359 structures with features
# Saved 360 structures with features
# Saved 361 structures with features
# Saved 362 structures with features
# Saved 363 structures with features
# Saved 364 structures with features
# Saved 365 structures with features
# Saved 366 structures with features
# Saved 367 structures with features
# Saved 368 structures with features
# Saved 369 structures with features
# Saved 370 structures with features
# Saved 371 structures with features
# Saved 372 structures with features
# Saved 373 structures with features
# Saved 374 structures with features
# Saved 375 structures with features
# Saved 376 structures with features
# Saved 377 structures with features
# Saved 378 structures with features
# Saved 379 structures with features
# Saved 380 structures with features
# Saved 381 structures with features
# Saved 382 structures with features
# Saved 383 structures with features
# Saved 384 structures with features
# Saved 385 structures with features
# Saved 386 structures with features
# Saved 387 structures with features
# Saved 388 structures with features
# Saved 389 structures with features
# Saved 390 structures with features
# Saved 391 structures with features
# Saved 392 structures with features
# Saved 393 structures with features
# Saved 394 structures with features
# Saved 395 structures with features
# Saved 396 structures with features
# Saved 397 structures with features
# Saved 398 structures with features
# Saved 399 structures with features
# Saved 400 structures with features
# Saved 401 structures with features
# Saved 402 structures with features
# Saved 403 structures with features
# Saved 404 structures with features
# Saved 405 structures with features
# Saved 406 structures with features
# Saved 407 structures with features
# Saved 408 structures with features
# Saved 409 structures with features
# Saved 410 structures with features
# Saved 411 structures with features
# Saved 412 structures with features
# Saved 413 structures with features
# Saved 414 structures with features
# Saved 415 structures with features
# Saved 416 structures with features
# Saved 417 structures with features
# Saved 418 structures with features
# Saved 419 structures with features
# Saved 420 structures with features
# Saved 421 structures with features
# Saved 422 structures with features
# Saved 423 structures with features
# Saved 424 structures with features
# Saved 425 structures with features
# Saved 426 structures with features
# Saved 427 structures with features
# Saved 428 structures with features
# Saved 429 structures with features
# Saved 430 structures with features
# Saved 431 structures with features
# Saved 432 structures with features
# Saved 433 structures with features
# Saved 434 structures with features
# Saved 435 structures with features
# Saved 436 structures with features
# Saved 437 structures with features
# Saved 438 structures with features
# Saved 439 structures with features
# Saved 440 structures with features
# Saved 441 structures with features
# Saved 442 structures with features
# Saved 443 structures with features
# Saved 444 structures with features
# Saved 445 structures with features
# Saved 446 structures with features
# Saved 447 structures with features
# Saved 448 structures with features
# Saved 449 structures with features
# Saved 450 structures with features
# Saved 451 structures with features
# Saved 452 structures with features
# Saved 453 structures with features
# Saved 454 structures with features
# Saved 455 structures with features
# Saved 456 structures with features
# Saved 457 structures with features
# Saved 458 structures with features
# Saved 459 structures with features
# Saved 460 structures with features
# Saved 461 structures with features
# Saved 462 structures with features
# Saved 463 structures with features
# Saved 464 structures with features
# Saved 465 structures with features
# Saved 466 structures with features
# Saved 467 structures with features
# Saved 468 structures with features
# Saved 469 structures with features
# Saved 470 structures with features
# Saved 471 structures with features
# Saved 472 structures with features
# Saved 473 structures with features
# Saved 474 structures with features
# Saved 475 structures with features
# Saved 476 structures with features
# Saved 477 structures with features
# Saved 478 structures with features
# Saved 479 structures with features
# Saved 480 structures with features
# Saved 481 structures with features
# Saved 482 structures with features
# Saved 483 structures with features
# Saved 484 structures with features
# Saved 485 structures with features
# Saved 486 structures with features
# Saved 487 structures with features
# Saved 488 structures with features
# Saved 489 structures with features
# Saved 490 structures with features
# Saved 491 structures with features
# Saved 492 structures with features
# Saved 493 structures with features
# Saved 494 structures with features
# Saved 495 structures with features
# Saved 496 structures with features
# Saved 497 structures with features
# Saved 498 structures with features
# Saved 499 structures with features
# Saved 500 structures with features
# Saved 501 structures with features
# Saved 502 structures with features
# Saved 503 structures with features
# Saved 504 structures with features
# Saved 505 structures with features
# Saved 506 structures with features
# Saved 507 structures with features
# Saved 508 structures with features
# Saved 509 structures with features
# Saved 510 structures with features
# Saved 511 structures with features
# Saved 512 structures with features
# Saved 513 structures with features
# Saved 514 structures with features
# Saved 515 structures with features
# Saved 516 structures with features
# Saved 517 structures with features
# Saved 518 structures with features
# Saved 519 structures with features
# Saved 520 structures with features
# Saved 521 structures with features
# Saved 522 structures with features
# Saved 523 structures with features
# Saved 524 structures with features
# Saved 525 structures with features
# Saved 526 structures with features
# Saved 527 structures with features
# Saved 528 structures with features
# Saved 529 structures with features
# Saved 530 structures with features
# Saved 531 structures with features
# Saved 532 structures with features
# Saved 533 structures with features
# Saved 534 structures with features
# Saved 535 structures with features
# Saved 536 structures with features
# Saved 537 structures with features
# Saved 538 structures with features
# Saved 539 structures with features
# Saved 540 structures with features
# Saved 541 structures with features
# Saved 542 structures with features
# Saved 543 structures with features
# Saved 544 structures with features
# Saved 545 structures with features
# Saved 546 structures with features
# Saved 547 structures with features
# Saved 548 structures with features
# Saved 549 structures with features
# Saved 550 structures with features
# Saved 551 structures with features
# Saved 552 structures with features
# Saved 553 structures with features
# Saved 554 structures with features
# Saved 555 structures with features
# Saved 556 structures with features
# Saved 557 structures with features
# Saved 558 structures with features
# Saved 559 structures with features
# Saved 560 structures with features
# Saved 561 structures with features
# Saved 562 structures with features
# Saved 563 structures with features
# Saved 564 structures with features
# Saved 565 structures with features
# Saved 566 structures with features
# Saved 567 structures with features
# Saved 568 structures with features
# Saved 569 structures with features
# Saved 570 structures with features
# Saved 571 structures with features
# Saved 572 structures with features
# Saved 573 structures with features
# Saved 574 structures with features
# Saved 575 structures with features
# Saved 576 structures with features
# Saved 577 structures with features
# Saved 578 structures with features
# Saved 579 structures with features
# Saved 580 structures with features
# Saved 581 structures with features
# Saved 582 structures with features
# Saved 583 structures with features
# Saved 584 structures with features
# Saved 585 structures with features
# Saved 586 structures with features
# Saved 587 structures with features
# Saved 588 structures with features
# Saved 589 structures with features
# Saved 590 structures with features
# Saved 591 structures with features
# Saved 592 structures with features
# Saved 593 structures with features
# Saved 594 structures with features
# Saved 595 structures with features
# Saved 596 structures with features
# Saved 597 structures with features
# Saved 598 structures with features
# Saved 599 structures with features
# Saved 600 structures with features
# Saved 601 structures with features
# Saved 602 structures with features
# Saved 603 structures with features
# Saved 604 structures with features
# Saved 605 structures with features
# Saved 606 structures with features
# Saved 607 structures with features
# Saved 608 structures with features
# Saved 609 structures with features
# Saved 610 structures with features
# Saved 611 structures with features
# Saved 612 structures with features
# Saved 613 structures with features
# Saved 614 structures with features
# Saved 615 structures with features
# Saved 616 structures with features
# Saved 617 structures with features
# Saved 618 structures with features
# Saved 619 structures with features
# Saved 620 structures with features
# Saved 621 structures with features
# Saved 622 structures with features
# Saved 623 structures with features
# Saved 624 structures with features
# Saved 625 structures with features
# Saved 626 structures with features
# Saved 627 structures with features
# Saved 628 structures with features
# Saved 629 structures with features
# Saved 630 structures with features
# Saved 631 structures with features
# Saved 632 structures with features
# Saved 633 structures with features
# Saved 634 structures with features
# Saved 635 structures with features
# Saved 636 structures with features
# Saved 637 structures with features
# Saved 638 structures with features
# Saved 639 structures with features
# Saved 640 structures with features
# Saved 641 structures with features
# Saved 642 structures with features
# Saved 643 structures with features
# Saved 644 structures with features
# Saved 645 structures with features
# Saved 646 structures with features
# Saved 647 structures with features
# Saved 648 structures with features
# Saved 649 structures with features
# Saved 650 structures with features
# Saved 651 structures with features
# Saved 652 structures with features
# Saved 653 structures with features
# Saved 654 structures with features
# Saved 655 structures with features
# Saved 656 structures with features
# Saved 657 structures with features
# Saved 658 structures with features
# Saved 659 structures with features
# Saved 660 structures with features
# Saved 661 structures with features
# Saved 662 structures with features
# Saved 663 structures with features
# Saved 664 structures with features
# Saved 665 structures with features
# Saved 666 structures with features
# Saved 667 structures with features
# Saved 668 structures with features
# Saved 669 structures with features
# Saved 670 structures with features
# Saved 671 structures with features
# Saved 672 structures with features
# Saved 673 structures with features
# Saved 674 structures with features
# Saved 675 structures with features
# Saved 676 structures with features
# Saved 677 structures with features
# Saved 678 structures with features
# Saved 679 structures with features
# Saved 680 structures with features
# Saved 681 structures with features
# Saved 682 structures with features
# Saved 683 structures with features
# Saved 684 structures with features
# Saved 685 structures with features
# Saved 686 structures with features
# Saved 687 structures with features
# Saved 688 structures with features
# Saved 689 structures with features
# Saved 690 structures with features
# Saved 691 structures with features
# Saved 692 structures with features
# Saved 693 structures with features
# Saved 694 structures with features
# Saved 695 structures with features
# Saved 696 structures with features
# Saved 697 structures with features
# Saved 698 structures with features
# Saved 699 structures with features
# Saved 700 structures with features
# Saved 701 structures with features
# Saved 702 structures with features
# Saved 703 structures with features
# Saved 704 structures with features
# Saved 705 structures with features
# Saved 706 structures with features
# Saved 707 structures with features
# Saved 708 structures with features
# Saved 709 structures with features
# Saved 710 structures with features
# Saved 711 structures with features
# Saved 712 structures with features
# Saved 713 structures with features
# Saved 714 structures with features
# Saved 715 structures with features
# Saved 716 structures with features
# Saved 717 structures with features
# Saved 718 structures with features
# Saved 719 structures with features
# Saved 720 structures with features
# Saved 721 structures with features
# Saved 722 structures with features
# Saved 723 structures with features
# Saved 724 structures with features
# Saved 725 structures with features
# Saved 726 structures with features
# Saved 727 structures with features
# Saved 728 structures with features
# Saved 729 structures with features
# Saved 730 structures with features
# Saved 731 structures with features
# Saved 732 structures with features
# Saved 733 structures with features
# Saved 734 structures with features
# Saved 735 structures with features
# Saved 736 structures with features
# Saved 737 structures with features
# Saved 738 structures with features
# Saved 739 structures with features
# Saved 740 structures with features
# Saved 741 structures with features
# Saved 742 structures with features
# Saved 743 structures with features
# Saved 744 structures with features
# Saved 745 structures with features
# Saved 746 structures with features
# Saved 747 structures with features
# Saved 748 structures with features
# Saved 749 structures with features
# Saved 750 structures with features
# Saved 751 structures with features
# Saved 752 structures with features
# Saved 753 structures with features
# Saved 754 structures with features
# Saved 755 structures with features
# Saved 756 structures with features
# Saved 757 structures with features
# Saved 758 structures with features
# Saved 759 structures with features
# Saved 760 structures with features
# Saved 761 structures with features
# Saved 762 structures with features
# Saved 763 structures with features
# Saved 764 structures with features
# Saved 765 structures with features
# Saved 766 structures with features
# Saved 767 structures with features
# Saved 768 structures with features
# Saved 769 structures with features
# Saved 770 structures with features
# Saved 771 structures with features
# Saved 772 structures with features
# Saved 773 structures with features
# Saved 774 structures with features
# Saved 775 structures with features
# Saved 776 structures with features
# Saved 777 structures with features
# Saved 778 structures with features
# Saved 779 structures with features
# Saved 780 structures with features
# Saved 781 structures with features
# Saved 782 structures with features
# Saved 783 structures with features
# Saved 784 structures with features
# Saved 785 structures with features
# Saved 786 structures with features
# Saved 787 structures with features
# Saved 788 structures with features
# Saved 789 structures with features
# Saved 790 structures with features
# Saved 791 structures with features
# Saved 792 structures with features
# Saved 793 structures with features
# Saved 794 structures with features
# Saved 795 structures with features
# Saved 796 structures with features
# Saved 797 structures with features
# Saved 798 structures with features
# Saved 799 structures with features
# Saved 800 structures with features
# Saved 801 structures with features
# Saved 802 structures with features
# Saved 803 structures with features
# Saved 804 structures with features
# Saved 805 structures with features
# Saved 806 structures with features
# Saved 807 structures with features
# Saved 808 structures with features
# Saved 809 structures with features
# Saved 810 structures with features
# Saved 811 structures with features
# Saved 812 structures with features
# Saved 813 structures with features
# Saved 814 structures with features
# Saved 815 structures with features
# Saved 816 structures with features
# Saved 817 structures with features
# Saved 818 structures with features
# Saved 819 structures with features
# Saved 820 structures with features
# Saved 821 structures with features
# Saved 822 structures with features
# Saved 823 structures with features
# Saved 824 structures with features
# Saved 825 structures with features
# Saved 826 structures with features
# Saved 827 structures with features
# Saved 828 structures with features
# Saved 829 structures with features
# Saved 830 structures with features
# Saved 831 structures with features
# Saved 832 structures with features
# Saved 833 structures with features
# Saved 834 structures with features
# Saved 835 structures with features
# Saved 836 structures with features
# Saved 837 structures with features
# Saved 838 structures with features
# Saved 839 structures with features
# Saved 840 structures with features
# Saved 841 structures with features
# Saved 842 structures with features
# Saved 843 structures with features
# Saved 844 structures with features
# Saved 845 structures with features
# Saved 846 structures with features
# Saved 847 structures with features
# Saved 848 structures with features
# Saved 849 structures with features
# Saved 850 structures with features
# Saved 851 structures with features
# Saved 852 structures with features
# Saved 853 structures with features
# Saved 854 structures with features
# Saved 855 structures with features
# Saved 856 structures with features
# Saved 857 structures with features
# Saved 858 structures with features
# Saved 859 structures with features
# Saved 860 structures with features
# Saved 861 structures with features
# Saved 862 structures with features
# Saved 863 structures with features
# Saved 864 structures with features
# Saved 865 structures with features
# Saved 866 structures with features
# Saved 867 structures with features
# Saved 868 structures with features
# Saved 869 structures with features
# Saved 870 structures with features
# Saved 871 structures with features
# Saved 872 structures with features
# Saved 873 structures with features
# Saved 874 structures with features
# Saved 875 structures with features
# Saved 876 structures with features
# Saved 877 structures with features
# Saved 878 structures with features
# Saved 879 structures with features
# Saved 880 structures with features
# Saved 881 structures with features
# Saved 882 structures with features
# Saved 883 structures with features
# Saved 884 structures with features
# Saved 885 structures with features
# Saved 886 structures with features
# Saved 887 structures with features
# Saved 888 structures with features
# Saved 889 structures with features
# Saved 890 structures with features
# Saved 891 structures with features
# Saved 892 structures with features
# Saved 893 structures with features
# Saved 894 structures with features
# Saved 895 structures with features
# Saved 896 structures with features
# Saved 897 structures with features
# Saved 898 structures with features
# Saved 899 structures with features
# Saved 900 structures with features
# Saved 901 structures with features
# Saved 902 structures with features
# Saved 903 structures with features
# Saved 904 structures with features
# Saved 905 structures with features
# Saved 906 structures with features
# Saved 907 structures with features
# Saved 908 structures with features
# Saved 909 structures with features
# Saved 910 structures with features
# Saved 911 structures with features
# Saved 912 structures with features
# Saved 913 structures with features
# Saved 914 structures with features
# Saved 915 structures with features
# Saved 916 structures with features
# Saved 917 structures with features
# Saved 918 structures with features
# Saved 919 structures with features
# Saved 920 structures with features
# Saved 921 structures with features
# Saved 922 structures with features
# Saved 923 structures with features
# Saved 924 structures with features
# Saved 925 structures with features
# Saved 926 structures with features
# Saved 927 structures with features
# Saved 928 structures with features
# Saved 929 structures with features
# Saved 930 structures with features
# Saved 931 structures with features
# Saved 932 structures with features
# Saved 933 structures with features
# Saved 934 structures with features
# Saved 935 structures with features
# Saved 936 structures with features
# Saved 937 structures with features
# Saved 938 structures with features
# Saved 939 structures with features
# Saved 940 structures with features
# Saved 941 structures with features
# Saved 942 structures with features
# Saved 943 structures with features
# Saved 944 structures with features
# Saved 945 structures with features
# Saved 946 structures with features
# Saved 947 structures with features
# Saved 948 structures with features
# Saved 949 structures with features
# Saved 950 structures with features
# Saved 951 structures with features
# Saved 952 structures with features
# Saved 953 structures with features
# Saved 954 structures with features
# Saved 955 structures with features
# Saved 956 structures with features
# Saved 957 structures with features
# Saved 958 structures with features
# Saved 959 structures with features
# Saved 960 structures with features
# Saved 961 structures with features
# Saved 962 structures with features
# Saved 963 structures with features
# Saved 964 structures with features
# Saved 965 structures with features
# Saved 966 structures with features
# Saved 967 structures with features
# Saved 968 structures with features
# Saved 969 structures with features
# Saved 970 structures with features
# Saved 971 structures with features
# Saved 972 structures with features
# Saved 973 structures with features
# Saved 974 structures with features
# Saved 975 structures with features
# Saved 976 structures with features
# Saved 977 structures with features
# Saved 978 structures with features
# Saved 979 structures with features
# Saved 980 structures with features
# Saved 981 structures with features
# Saved 982 structures with features
# Saved 983 structures with features
# Saved 984 structures with features
# Saved 985 structures with features
# Saved 986 structures with features
# Saved 987 structures with features
# Saved 988 structures with features
# Saved 989 structures with features
# Saved 990 structures with features
# Saved 991 structures with features
# Saved 992 structures with features
# Saved 993 structures with features
# Saved 994 structures with features
# Saved 995 structures with features
# Saved 996 structures with features
# Saved 997 structures with features
# Saved 998 structures with features
# Saved 999 structures with features
# Saved 1000 structures with features
# Saved 1001 structures with features
# Saved 1002 structures with features
# Saved 1003 structures with features
# Saved 1004 structures with features
# Saved 1005 structures with features
# Saved 1006 structures with features
# Saved 1007 structures with features
# Saved 1008 structures with features
# Saved 1009 structures with features
# Saved 1010 structures with features
# Saved 1011 structures with features
# Saved 1012 structures with features
# Saved 1013 structures with features
# Saved 1014 structures with features
# Saved 1015 structures with features
# Saved 1016 structures with features
# Saved 1017 structures with features
# Saved 1018 structures with features
# Saved 1019 structures with features
# Saved 1020 structures with features
# Saved 1021 structures with features
# Saved 1022 structures with features
# Saved 1023 structures with features
# Saved 1024 structures with features
# Saved 1025 structures with features
# Saved 1026 structures with features
# Saved 1027 structures with features
# Saved 1028 structures with features
# Saved 1029 structures with features
# Saved 1030 structures with features
# Saved 1031 structures with features
# Saved 1032 structures with features
# Saved 1033 structures with features
# Saved 1034 structures with features
# Saved 1035 structures with features
# Saved 1036 structures with features
# Saved 1037 structures with features
# Saved 1038 structures with features
# Saved 1039 structures with features
# Saved 1040 structures with features
# Saved 1041 structures with features
# Saved 1042 structures with features
# Saved 1043 structures with features
# Saved 1044 structures with features
# Saved 1045 structures with features
# Saved 1046 structures with features
# Saved 1047 structures with features
# Saved 1048 structures with features
# Saved 1049 structures with features
# Saved 1050 structures with features
# Saved 1051 structures with features
# Saved 1052 structures with features
# Saved 1053 structures with features
# Saved 1054 structures with features
# Saved 1055 structures with features
# Saved 1056 structures with features
# Saved 1057 structures with features
# Saved 1058 structures with features
# Saved 1059 structures with features
# Saved 1060 structures with features
# Saved 1061 structures with features
# Saved 1062 structures with features
# Saved 1063 structures with features
# Saved 1064 structures with features
# Saved 1065 structures with features
# Saved 1066 structures with features
# Saved 1067 structures with features
# Saved 1068 structures with features
# Saved 1069 structures with features
# Saved 1070 structures with features
# Saved 1071 structures with features
# Saved 1072 structures with features
# Saved 1073 structures with features
# Saved 1074 structures with features
# Saved 1075 structures with features
# Saved 1076 structures with features
# Saved 1077 structures with features
# Saved 1078 structures with features
# Saved 1079 structures with features
# Saved 1080 structures with features
# Saved 1081 structures with features
# Saved 1082 structures with features
# Saved 1083 structures with features
# Saved 1084 structures with features
# Saved 1085 structures with features
# Saved 1086 structures with features
# Saved 1087 structures with features
# Saved 1088 structures with features
# Saved 1089 structures with features
# Saved 1090 structures with features
# Saved 1091 structures with features
# Saved 1092 structures with features
# Saved 1093 structures with features
# Saved 1094 structures with features
# Saved 1095 structures with features
# Saved 1096 structures with features
# Saved 1097 structures with features
# Saved 1098 structures with features
# Saved 1099 structures with features
# Saved 1100 structures with features
# Saved 1101 structures with features
# Saved 1102 structures with features
# Saved 1103 structures with features
# Saved 1104 structures with features
# Saved 1105 structures with features
# Saved 1106 structures with features
# Saved 1107 structures with features
# Saved 1108 structures with features
# Saved 1109 structures with features
# Saved 1110 structures with features
# Saved 1111 structures with features
# Saved 1112 structures with features
# Saved 1113 structures with features
# Saved 1114 structures with features
# Saved 1115 structures with features
# Saved 1116 structures with features
# Saved 1117 structures with features
# Saved 1118 structures with features
# Saved 1119 structures with features
# Saved 1120 structures with features
# Saved 1121 structures with features
# Saved 1122 structures with features
# Saved 1123 structures with features
# Saved 1124 structures with features
# Saved 1125 structures with features
# Saved 1126 structures with features
# Saved 1127 structures with features
# Saved 1128 structures with features
# Saved 1129 structures with features
# Saved 1130 structures with features
# Saved 1131 structures with features
# Saved 1132 structures with features
# Saved 1133 structures with features
# Saved 1134 structures with features
# Saved 1135 structures with features
# Saved 1136 structures with features
# Saved 1137 structures with features
# Saved 1138 structures with features
# Saved 1139 structures with features
# Saved 1140 structures with features
# Saved 1141 structures with features
# Saved 1142 structures with features
# Saved 1143 structures with features
# Saved 1144 structures with features
# Saved 1145 structures with features
# Saved 1146 structures with features
# Saved 1147 structures with features
# Saved 1148 structures with features
# Saved 1149 structures with features
# Saved 1150 structures with features
# Saved 1151 structures with features
# Saved 1152 structures with features
# Saved 1153 structures with features
# Saved 1154 structures with features
# Saved 1155 structures with features
# Saved 1156 structures with features
# Saved 1157 structures with features
# Saved 1158 structures with features
# Saved 1159 structures with features
# Saved 1160 structures with features
# Saved 1161 structures with features
# Saved 1162 structures with features
# Saved 1163 structures with features
# Saved 1164 structures with features
# Saved 1165 structures with features
# Saved 1166 structures with features
# Saved 1167 structures with features
# Saved 1168 structures with features
# Saved 1169 structures with features
# Saved 1170 structures with features
# Saved 1171 structures with features
# Saved 1172 structures with features
# Saved 1173 structures with features
# Saved 1174 structures with features
# Saved 1175 structures with features
# Saved 1176 structures with features
# Saved 1177 structures with features
# Saved 1178 structures with features
# Saved 1179 structures with features
# Saved 1180 structures with features
# Saved 1181 structures with features
# Saved 1182 structures with features
# Saved 1183 structures with features
# Saved 1184 structures with features
# Saved 1185 structures with features
# Saved 1186 structures with features
# Saved 1187 structures with features
# Saved 1188 structures with features
# Saved 1189 structures with features
# Saved 1190 structures with features
# Saved 1191 structures with features
# Saved 1192 structures with features
# Saved 1193 structures with features
# Saved 1194 structures with features
# Saved 1195 structures with features
# Saved 1196 structures with features
# Saved 1197 structures with features
# Saved 1198 structures with features
# Saved 1199 structures with features
# Saved 1200 structures with features
# Saved 1201 structures with features
# Saved 1202 structures with features
# Saved 1203 structures with features
# Saved 1204 structures with features
# Saved 1205 structures with features
# Saved 1206 structures with features
# Saved 1207 structures with features
# Saved 1208 structures with features
# Saved 1209 structures with features
# Saved 1210 structures with features
# Saved 1211 structures with features
# Saved 1212 structures with features
# Saved 1213 structures with features
# Saved 1214 structures with features
# Saved 1215 structures with features
# Saved 1216 structures with features
# Saved 1217 structures with features
# Saved 1218 structures with features
# Saved 1219 structures with features
# Saved 1220 structures with features
# Saved 1221 structures with features
# Saved 1222 structures with features
# Saved 1223 structures with features
# Saved 1224 structures with features
# Saved 1225 structures with features
# Saved 1226 structures with features
# Saved 1227 structures with features
# Saved 1228 structures with features
# Saved 1229 structures with features
# Saved 1230 structures with features
# Saved 1231 structures with features
# Saved 1232 structures with features
# Saved 1233 structures with features
# Saved 1234 structures with features
# Saved 1235 structures with features
# Saved 1236 structures with features
# Saved 1237 structures with features
# Saved 1238 structures with features
# Saved 1239 structures with features
# Saved 1240 structures with features
# Saved 1241 structures with features
# Saved 1242 structures with features
# Saved 1243 structures with features
# Saved 1244 structures with features
# Saved 1245 structures with features
# Saved 1246 structures with features
# Saved 1247 structures with features
# Saved 1248 structures with features
# Saved 1249 structures with features
# Saved 1250 structures with features
# Saved 1251 structures with features
# Saved 1252 structures with features
# Saved 1253 structures with features
# Saved 1254 structures with features
# Saved 1255 structures with features
# Saved 1256 structures with features
# Saved 1257 structures with features
# Saved 1258 structures with features
# Saved 1259 structures with features
# Saved 1260 structures with features
# Saved 1261 structures with features
# Saved 1262 structures with features
# Saved 1263 structures with features
# Saved 1264 structures with features
# Saved 1265 structures with features
# Saved 1266 structures with features
# Saved 1267 structures with features
# Saved 1268 structures with features
# Saved 1269 structures with features
# Saved 1270 structures with features
# Saved 1271 structures with features
# Saved 1272 structures with features
# Saved 1273 structures with features
# Saved 1274 structures with features
# Saved 1275 structures with features
# Saved 1276 structures with features
# Saved 1277 structures with features
# Saved 1278 structures with features
# Saved 1279 structures with features
# Saved 1280 structures with features
# Saved 1281 structures with features
# Saved 1282 structures with features
# Saved 1283 structures with features
# Saved 1284 structures with features
# Saved 1285 structures with features
# Saved 1286 structures with features
# Saved 1287 structures with features
# Saved 1288 structures with features
# Saved 1289 structures with features
# Saved 1290 structures with features
# Saved 1291 structures with features
# Saved 1292 structures with features
# Saved 1293 structures with features
# Saved 1294 structures with features
# Saved 1295 structures with features
# Saved 1296 structures with features
# Saved 1297 structures with features
# Saved 1298 structures with features
# Saved 1299 structures with features
# Saved 1300 structures with features
# Saved 1301 structures with features
# Saved 1302 structures with features
# Saved 1303 structures with features
# Saved 1304 structures with features
# Saved 1305 structures with features
# Saved 1306 structures with features
# Saved 1307 structures with features
# Saved 1308 structures with features
# Saved 1309 structures with features
# Saved 1310 structures with features
# Saved 1311 structures with features
# Saved 1312 structures with features
# Saved 1313 structures with features
# Saved 1314 structures with features
# Saved 1315 structures with features
# Saved 1316 structures with features
# Saved 1317 structures with features
# Saved 1318 structures with features
# Saved 1319 structures with features
# Saved 1320 structures with features
# Saved 1321 structures with features
# Saved 1322 structures with features
# Saved 1323 structures with features
# Saved 1324 structures with features
# Saved 1325 structures with features
# Saved 1326 structures with features
# Saved 1327 structures with features
# Saved 1328 structures with features
# Saved 1329 structures with features
# Saved 1330 structures with features
# Saved 1331 structures with features
# Saved 1332 structures with features
# Saved 1333 structures with features
# Saved 1334 structures with features
# Saved 1335 structures with features
# Saved 1336 structures with features
# Saved 1337 structures with features
# Saved 1338 structures with features
# Saved 1339 structures with features
# Saved 1340 structures with features
# Saved 1341 structures with features
# Saved 1342 structures with features
# Saved 1343 structures with features
# Saved 1344 structures with features
# Saved 1345 structures with features
# Saved 1346 structures with features
# Saved 1347 structures with features
# Saved 1348 structures with features
# Saved 1349 structures with features
# Saved 1350 structures with features
# Saved 1351 structures with features
# Saved 1352 structures with features
# Saved 1353 structures with features
# Saved 1354 structures with features
# Saved 1355 structures with features
# Saved 1356 structures with features
# Saved 1357 structures with features
# Saved 1358 structures with features
# Saved 1359 structures with features
# Saved 1360 structures with features
# Saved 1361 structures with features
# Saved 1362 structures with features
# Saved 1363 structures with features
# Saved 1364 structures with features
# ...
# Saved 3741 structures with features
# Saved 3742 structures with features
# Saved 3743 structures with features
# Saved 3744 structures with features
# Saved 3745 structures with features
# Saved 3746 structures with features
# Saved 3747 structures with features
# Saved 3748 structures with features
# Saved 3749 structures with features
# Saved 3750 structures with features
# Saved 3751 structures with features
# Saved 3752 structures with features
# Saved 3753 structures with features
# Saved 3754 structures with features
# Saved 3755 structures with features
# Saved 3756 structures with features
# Saved 3757 structures with features
# Saved 3758 structures with features
# Saved 3759 structures with features
# Saved 3760 structures with features
# Saved 3761 structures with features
# Saved 3762 structures with features
# Saved 3763 structures with features
# Saved 3764 structures with features
# Saved 3765 structures with features
# Saved 3766 structures with features
# Saved 3767 structures with features
# Saved 3768 structures with features
# Saved 3769 structures with features
# Saved 3770 structures with features
# Saved 3771 structures with features
# Saved 3772 structures with features
# Saved 3773 structures with features
# Saved 3774 structures with features
# Saved 3775 structures with features
# Saved 3776 structures with features
# Saved 3777 structures with features
# Saved 3778 structures with features
# Saved 3779 structures with features
# Saved 3780 structures with features
# Saved 3781 structures with features
# Saved 3782 structures with features
# Saved 3783 structures with features
# Saved 3784 structures with features
# Saved 3785 structures with features
# Saved 3786 structures with features
# Saved 3787 structures with features
# Saved 3788 structures with features
# Saved 3789 structures with features
# Saved 3790 structures with features
# Saved 3791 structures with features
# Saved 3792 structures with features
# Saved 3793 structures with features
# Saved 3794 structures with features
# Saved 3795 structures with features
# Saved 3796 structures with features
# Saved 3797 structures with features
# Saved 3798 structures with features
# Saved 3799 structures with features
# Saved 3800 structures with features
# Saved 3801 structures with features
# Saved 3802 structures with features
# Saved 3803 structures with features
# Saved 3804 structures with features
# Saved 3805 structures with features
# Saved 3806 structures with features
# Saved 3807 structures with features
# Saved 3808 structures with features
# Saved 3809 structures with features
# Saved 3810 structures with features
# Saved 3811 structures with features
# Saved 3812 structures with features
# Saved 3813 structures with features
# Saved 3814 structures with features
# Saved 3815 structures with features
# Saved 3816 structures with features
# Saved 3817 structures with features
# Saved 3818 structures with features
# Saved 3819 structures with features
# Saved 3820 structures with features
# Saved 3821 structures with features
# Saved 3822 structures with features
# Saved 3823 structures with features
# Saved 3824 structures with features
# Saved 3825 structures with features
# Saved 3826 structures with features
# Saved 3827 structures with features
# Saved 3828 structures with features
# Saved 3829 structures with features
# Saved 3830 structures with features
# Saved 3831 structures with features
# Saved 3832 structures with features
# Saved 3833 structures with features
# Saved 3834 structures with features
# Saved 3835 structures with features
# Saved 3836 structures with features
# Saved 3837 structures with features
# Saved 3838 structures with features
# Saved 3839 structures with features
# Saved 3840 structures with features
# Saved 3841 structures with features
# Saved 3842 structures with features
# Saved 3843 structures with features
# Saved 3844 structures with features
# Saved 3845 structures with features
# Saved 3846 structures with features
# Saved 3847 structures with features
# Saved 3848 structures with features
# Saved 3849 structures with features
# Saved 3850 structures with features
# Saved 3851 structures with features
# Saved 3852 structures with features
# Saved 3853 structures with features
# Saved 3854 structures with features
# Saved 3855 structures with features
# Saved 3856 structures with features
# Saved 3857 structures with features
# Saved 3858 structures with features
# Saved 3859 structures with features
# Saved 3860 structures with features
# Saved 3861 structures with features
# Saved 3862 structures with features
# Saved 3863 structures with features
# Saved 3864 structures with features
# Saved 3865 structures with features
# Saved 3866 structures with features
# Saved 3867 structures with features
# Saved 3868 structures with features
# Saved 3869 structures with features
# Saved 3870 structures with features
# Saved 3871 structures with features
# Saved 3872 structures with features
# Saved 3873 structures with features
# Saved 3874 structures with features
# Saved 3875 structures with features
# Saved 3876 structures with features
# Saved 3877 structures with features
# Saved 3878 structures with features
# Saved 3879 structures with features
# Saved 3880 structures with features
# Saved 3881 structures with features
# Saved 3882 structures with features
# Saved 3883 structures with features
# Saved 3884 structures with features
# Saved 3885 structures with features
# Saved 3886 structures with features
# Saved 3887 structures with features
# Saved 3888 structures with features
# Saved 3889 structures with features
# Saved 3890 structures with features
# Saved 3891 structures with features
# Saved 3892 structures with features
# Saved 3893 structures with features
# Saved 3894 structures with features
# Saved 3895 structures with features
# Saved 3896 structures with features
# Saved 3897 structures with features
# Saved 3898 structures with features
# Saved 3899 structures with features
# Saved 3900 structures with features
# Saved 3901 structures with features
# Saved 3902 structures with features
# Saved 3903 structures with features
# Saved 3904 structures with features
# Saved 3905 structures with features
# Saved 3906 structures with features
# Saved 3907 structures with features
# Saved 3908 structures with features
# Saved 3909 structures with features
# Saved 3910 structures with features
# Saved 3911 structures with features
# Saved 3912 structures with features
# Saved 3913 structures with features
# Saved 3914 structures with features
# Saved 3915 structures with features
# Saved 3916 structures with features
# Saved 3917 structures with features
# Saved 3918 structures with features
# Saved 3919 structures with features
# Saved 3920 structures with features
# Saved 3921 structures with features
# Saved 3922 structures with features
# Saved 3923 structures with features
# Saved 3924 structures with features
# Saved 3925 structures with features
# Saved 3926 structures with features
# Saved 3927 structures with features
# Saved 3928 structures with features
# Saved 3929 structures with features
# Saved 3930 structures with features
# Saved 3931 structures with features
# Saved 3932 structures with features
# Saved 3933 structures with features
# Saved 3934 structures with features
# Saved 3935 structures with features
# Saved 3936 structures with features
# Saved 3937 structures with features
# Saved 3938 structures with features
# Saved 3939 structures with features
# Saved 3940 structures with features
# Saved 3941 structures with features
# Saved 3942 structures with features
# Saved 3943 structures with features
# Saved 3944 structures with features
# Saved 3945 structures with features
# Saved 3946 structures with features
# Saved 3947 structures with features
# Saved 3948 structures with features
# Saved 3949 structures with features
# Saved 3950 structures with features
# Saved 3951 structures with features
# Saved 3952 structures with features
# Saved 3953 structures with features
# Saved 3954 structures with features
# Saved 3955 structures with features
# Saved 3956 structures with features
# Saved 3957 structures with features
# Saved 3958 structures with features
# Saved 3959 structures with features
# Saved 3960 structures with features
# Saved 3961 structures with features
# Saved 3962 structures with features
# Saved 3963 structures with features
# Saved 3964 structures with features
# Saved 3965 structures with features
# Saved 3966 structures with features
# Saved 3967 structures with features
# Saved 3968 structures with features
# Saved 3969 structures with features
# Saved 3970 structures with features
# Saved 3971 structures with features
# Saved 3972 structures with features
# Saved 3973 structures with features
# Saved 3974 structures with features
# Saved 3975 structures with features
# Saved 3976 structures with features
# Saved 3977 structures with features
# Saved 3978 structures with features
# Saved 3979 structures with features
# Saved 3980 structures with features
# Saved 3981 structures with features
# Saved 3982 structures with features
# Saved 3983 structures with features
# Saved 3984 structures with features
# Saved 3985 structures with features
# Saved 3986 structures with features
# Saved 3987 structures with features
# Saved 3988 structures with features
# Saved 3989 structures with features
# Saved 3990 structures with features
# Saved 3991 structures with features
# Saved 3992 structures with features
# Saved 3993 structures with features
# Saved 3994 structures with features
# Saved 3995 structures with features
# Saved 3996 structures with features
# Saved 3997 structures with features
# Saved 3998 structures with features
# Saved 3999 structures with features
# Saved 4000 structures with features
# Saved 4001 structures with features
# Saved 4002 structures with features
# Saved 4003 structures with features
# Saved 4004 structures with features
# Saved 4005 structures with features
# Saved 4006 structures with features
# Saved 4007 structures with features
# Saved 4008 structures with features
# Saved 4009 structures with features
# Saved 4010 structures with features
# Saved 4011 structures with features
# Saved 4012 structures with features
# Saved 4013 structures with features
# Saved 4014 structures with features
# Saved 4015 structures with features
# Saved 4016 structures with features
# Saved 4017 structures with features
# Saved 4018 structures with features
# Saved 4019 structures with features
# Saved 4020 structures with features
# Saved 4021 structures with features
# Saved 4022 structures with features
# Saved 4023 structures with features
# Saved 4024 structures with features
# Saved 4025 structures with features
# Saved 4026 structures with features
# Saved 4027 structures with features
# Saved 4028 structures with features
# Saved 4029 structures with features
# Saved 4030 structures with features
# Saved 4031 structures with features
# Saved 4032 structures with features
# Saved 4033 structures with features
# Saved 4034 structures with features
# Saved 4035 structures with features
# Saved 4036 structures with features
# Saved 4037 structures with features
# Saved 4038 structures with features
# Saved 4039 structures with features
# Saved 4040 structures with features
# Saved 4041 structures with features
# Saved 4042 structures with features
# Saved 4043 structures with features
# Saved 4044 structures with features
# Saved 4045 structures with features
# Saved 4046 structures with features
# Saved 4047 structures with features
# Saved 4048 structures with features
# Saved 4049 structures with features
# Saved 4050 structures with features
# Saved 4051 structures with features
# Saved 4052 structures with features
# Saved 4053 structures with features
# Saved 4054 structures with features
# Saved 4055 structures with features
# Saved 4056 structures with features
# Saved 4057 structures with features
# Saved 4058 structures with features
# Saved 4059 structures with features
# Saved 4060 structures with features
# Saved 4061 structures with features
# Saved 4062 structures with features
# Saved 4063 structures with features
# Saved 4064 structures with features
# Saved 4065 structures with features
# Saved 4066 structures with features
# Saved 4067 structures with features
# Saved 4068 structures with features
# Saved 4069 structures with features
# Saved 4070 structures with features
# Saved 4071 structures with features
# Saved 4072 structures with features
# Saved 4073 structures with features
# Saved 4074 structures with features
# Saved 4075 structures with features
# Saved 4076 structures with features
# Saved 4077 structures with features
# Saved 4078 structures with features
# Saved 4079 structures with features
# Saved 4080 structures with features
# Saved 4081 structures with features
# Saved 4082 structures with features
# Saved 4083 structures with features
# Saved 4084 structures with features
# Saved 4085 structures with features
# Saved 4086 structures with features
# Saved 4087 structures with features
# Saved 4088 structures with features
# Saved 4089 structures with features
# Saved 4090 structures with features
# Saved 4091 structures with features
# Saved 4092 structures with features
# Saved 4093 structures with features
# Saved 4094 structures with features
# Saved 4095 structures with features
# Saved 4096 structures with features
# Saved 4097 structures with features
# Saved 4098 structures with features
# Saved 4099 structures with features
# Saved 4100 structures with features
# Saved 4101 structures with features
# Saved 4102 structures with features
# Saved 4103 structures with features
# Saved 4104 structures with features
# Saved 4105 structures with features
# Saved 4106 structures with features
# Saved 4107 structures with features
# Saved 4108 structures with features
# Saved 4109 structures with features
# Saved 4110 structures with features
# Saved 4111 structures with features
# Saved 4112 structures with features
# Saved 4113 structures with features
# Saved 4114 structures with features
# Saved 4115 structures with features
# Saved 4116 structures with features
# Saved 4117 structures with features
# Saved 4118 structures with features
# Saved 4119 structures with features
# Saved 4120 structures with features
# Saved 4121 structures with features
# Saved 4122 structures with features
# Saved 4123 structures with features
# Saved 4124 structures with features
# Saved 4125 structures with features
# Saved 4126 structures with features
# Saved 4127 structures with features
# Saved 4128 structures with features
# Saved 4129 structures with features
# Saved 4130 structures with features
# Saved 4131 structures with features
# Saved 4132 structures with features
# Saved 4133 structures with features
# Saved 4134 structures with features
# Saved 4135 structures with features
# Saved 4136 structures with features
# Saved 4137 structures with features
# Saved 4138 structures with features
# Saved 4139 structures with features
# Saved 4140 structures with features
# Saved 4141 structures with features
# Saved 4142 structures with features
# Saved 4143 structures with features
# Saved 4144 structures with features
# Saved 4145 structures with features
# Saved 4146 structures with features
# Saved 4147 structures with features
# Saved 4148 structures with features
# Saved 4149 structures with features
# Saved 4150 structures with features
# Saved 4151 structures with features
# Saved 4152 structures with features
# Saved 4153 structures with features
# Saved 4154 structures with features
# Saved 4155 structures with features
# Saved 4156 structures with features
# Saved 4157 structures with features
# Saved 4158 structures with features
# Saved 4159 structures with features
# Saved 4160 structures with features
# Saved 4161 structures with features
# Saved 4162 structures with features
# Saved 4163 structures with features
# Saved 4164 structures with features
# Saved 4165 structures with features
# Saved 4166 structures with features
# Saved 4167 structures with features
# Saved 4168 structures with features
# Saved 4169 structures with features
# Saved 4170 structures with features
# Saved 4171 structures with features
# Saved 4172 structures with features
# Saved 4173 structures with features
# Saved 4174 structures with features
# Saved 4175 structures with features
# Saved 4176 structures with features
# Saved 4177 structures with features
# Saved 4178 structures with features
# Saved 4179 structures with features
# Saved 4180 structures with features
# Saved 4181 structures with features
# Saved 4182 structures with features
# Saved 4183 structures with features
# Saved 4184 structures with features

# %%
fig,axes=plt.subplots(2,3,figsize=(14,8))
features=[
    ('electronegativity_diff','Electronegativity Diff'),
    ('mean_atomicmass','Mean Atomic Mass'),
    ('density','Density'),
    ('volume_per_atm','Volume per Atom'),
    ('mean_row','Mean Period'),
    ('mean_group','Mean Group'),]
for ax,(feat,label) in zip(axes.flat,features):
    ax.scatter(df_struct[feat],df_struct['bandgap'],
               alpha=0.3,s=10,color='#534AB7')
    corr=df_struct[feat].corr(df_struct['bandgap'])
    ax.set_xlabel(label)
    ax.set_ylabel('Bandgap (eV)')
    ax.set_title(f'r={corr:.3f}')
plt.tight_layout()
plt.savefig('day3_feature_correlations.png',dpi=150)
plt.show()

# %%
import json
structures_json=[]
for entry in entries:
    structures_json.append({
        "material_id": entry.material_id,
        "formula": entry.formula_pretty,
        "bandgap": entry.band_gap,
        "structure": entry.structure.as_dict()})
with open("structures.json","w") as f:
    json.dump(structures_json,f)
print(f"Saved {len(structures_json)} structures!")
# Out:
# Saved 4184 structures!

# %%
from pymatgen.io.cif import CifWriter

cif_text = str(CifWriter(entries[0].structure))

with open("test_structure.cif", "wt", encoding="utf-8") as f:
    f.write(cif_text)
